# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
df1 = pd.read_csv('df1.csv', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.9, figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(figsize=(12,6)) # Categorical
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(figsize=(12,6), stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1.plot.line(y='B', figsize=(12,2), lw=1)
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x='A', y='B', c='C', figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*100, figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box(figsize=(12,3))
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a', 'b'])

# %%
df.head()
# Out:
#           a         b
# 0 -0.823488 -0.044705
# 1 -2.076420  0.278444
# 2  0.355749  0.086696
# 3 -0.971225  1.136814
# 4  1.108180  1.402193

# %%
df.plot.hexbin(x='a', y='b', figsize=(12,10), gridsize=25) # works only with bi-variate
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df['a'].plot.kde(figsize=(12,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density(figsize=(12,6))
# Out:
# <AxesSubplot:ylabel='Density'>
